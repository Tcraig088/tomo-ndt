# %%
from tomondt.data import VolumeTimeSeries

vtd = VolumeTimeSeries.read(r'\\ematbyname\emat\TimC\DIPSTER-PublicationData\Finalized_Samples\Volumes(VMF)\Cage-D_sage-forest-34.vmf')
# Out:
# 2026-03-17 12:22:54,542 - WARNING - CuPy is not installed. GPU acceleration will not be available.
# 2026-03-17 12:22:54,743 - DEBUG - Updating registry with hook 'is_tomobase_phantom' (explicit=False)
# 2026-03-17 12:22:54,743 - DEBUG - Scanning D:\Code\Github\TimeDependentTomography\submodules\tomobase\tomobase for is_tomobase_phantom items
# 2026-03-17 12:22:54,743 - DEBUG - Importing tomobase.environment to check for is_tomobase_phantom items
# 2026-03-17 12:22:54,743 - DEBUG - Importing tomobase.log to check for is_tomobase_phantom items
# 2026-03-17 12:22:54,743 - DEBUG - Importing tomobase.utils to check for is_tomobase_phantom items
# 2026-03-17 12:22:54,859 - DEBUG - Importing tomobase.__init__ to check for is_tomobase_phantom items
# 2026-03-17 12:22:54,859 - DEBUG - Added category 'Deform' -> 0x3c000000 (inheritor=None)
# 2026-03-17 12:22:54,859 - DEBUG - Added category 'Image Processing' -> 0x40000000 (inheritor=None)
# ...

# %%
import stackview

stackview.slice(vtd.data)

# %%
print(type(vtd.data))
print(type(vtd.data.data))
print(vtd.data.data)
print(len(vtd.data.data.dask))
# Out:
# <class 'xarray.core.dataarray.DataArray'>
# <class 'dask.array.core.Array'>
# dask.array<stack, shape=(100, 128, 128, 128), dtype=float32, chunksize=(1, 128, 128, 128), chunktype=numpy.ndarray>
# 300
